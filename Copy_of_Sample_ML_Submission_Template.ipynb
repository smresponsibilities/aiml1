# %% [markdown]
# <a href="https://colab.research.google.com/github/smresponsibilities/aiml1/blob/main/Copy_of_Sample_ML_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA/Regression
# ##### **Contribution**    - Team
# ##### **Team Member 1 -** Sheenam Dubey
# ##### **Team Member 2 -** Sejal Bansal
# ##### **Team Member 3 -** Shivam Mahajan
# ##### **Team Member 4 -** Shivam Gupta

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# In this ambitious project, we embark on a comprehensive endeavor to develop a robust time series forecasting model aimed at predicting Tesla stock prices using historical market data. Our journey begins with meticulous data preprocessing, where we employ rigorous techniques to handle missing values, scale, and normalize the dataset, ensuring its integrity and reliability. Moving forward, we delve into the realm of feature engineering, where advanced methodologies are employed to extract meaningful features from the raw data, capturing intricate patterns and trends that influence Tesla stock prices. Armed with these engineered features, we proceed to experiment with a diverse range of state-of-the-art algorithms, including AutoRegressive Integrated Moving Average (ARIMA), Long Short-Term Memory (LSTM), and Prophet models, each meticulously configured and trained on the preprocessed dataset. Throughout the experimentation phase, we conduct rigorous evaluations using robust evaluation metrics such as Mean Squared Error (MSE) and Mean Absolute Error (MAE), aiming to identify the most accurate and reliable forecasting model. Our results showcase the model's ability to accurately predict Tesla stock prices, providing stakeholders with invaluable insights into market dynamics and trends. Additionally, we offer comprehensive visualizations and analyses of predicted versus actual stock prices, enabling stakeholders to gain a deeper understanding of market behavior. Looking ahead, potential avenues for improvement include further refining feature engineering methodologies, exploring ensemble modeling techniques, and incorporating additional external factors that may influence stock prices. By leveraging advanced algorithms and data analysis techniques, this project contributes significantly to the field of time series forecasting, empowering investors and analysts with powerful tools to navigate the complexities of the stock market landscape and make informed decisions.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/shivam1514
#
# https://github.com/Sheenam7
#
# https://github.com/smresponsibilities
#
# https://github.com/Sejalbansal17

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Develop a time series forecasting model to predict tesla stock prices
# based on historical market data. This project involves data
# preprocessing, feature engineering, and experimenting with
# algorithms like ARIMA, LSTM, or Prophet.
#
# ---

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
tesla = pd.read_csv('/content/Tesla.csv')
tesla_data=tesla
t=tesla

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
tesla
# Out:
#            Date        Open        High         Low       Close    Volume  \
# 0     6/29/2010   19.000000   25.000000   17.540001   23.889999  18766300
# 1     6/30/2010   25.790001   30.420000   23.299999   23.830000  17187100
# 2      7/1/2010   25.000000   25.920000   20.270000   21.959999   8218800
# 3      7/2/2010   23.000000   23.100000   18.709999   19.200001   5139800
# 4      7/6/2010   20.000000   20.000000   15.830000   16.110001   6866900
# ...         ...         ...         ...         ...         ...       ...
# 1687  3/13/2017  244.820007  246.850006  242.779999  246.169998   3010700
# 1688  3/14/2017  246.110001  258.119995  246.020004  258.000000   7575500
# 1689  3/15/2017  257.000000  261.000000  254.270004  255.729996   4816600
# 1690  3/16/2017  262.399994  265.750000  259.059998  262.049988   7100400
# 1691  3/17/2017  264.000000  265.329987  261.200012  261.500000   6475900
#
#        Adj Close
# 0      23.889999
# 1      23.830000
# 2      21.959999
# 3      19.200001
# 4      16.110001
# ...          ...
# 1687  246.169998
# 1688  258.000000
# 1689  255.729996
# 1690  262.049988
# 1691  261.500000
#
# [1692 rows x 7 columns]

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
tesla.shape
# Out:
# (1692, 7)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1692 entries, 0 to 1691
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1692 non-null   object
#  1   Open       1692 non-null   float64
#  2   High       1692 non-null   float64
#  3   Low        1692 non-null   float64
#  4   Close      1692 non-null   float64
#  5   Volume     1692 non-null   int64
#  6   Adj Close  1692 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 92.7+ KB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
a=(tesla.count()-tesla.nunique()).reset_index()
a.columns=['Column name','Duplicate value count']
a
# Out:
#   Column name  Duplicate value count
# 0        Date                      0
# 1        Open                    228
# 2        High                    222
# 3         Low                    224
# 4       Close                    164
# 5      Volume                     16
# 6   Adj Close                    164

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
tesla.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
# Visualizing the missing values

plt.bar(tesla.isna().sum().index,tesla.isna().sum().values)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# ## 1)We know that the close and adj close colums are same as tesla doesn't do any share splitting, dividends etc.
# ## 2)Five values of open and close are equal.
# ## 3)The date column was of string datatype.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
tesla.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
# Dataset Describe
tesla.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1692.000000  1692.000000  1692.000000  1692.000000  1.692000e+03
# mean    132.441572   134.769698   129.996223   132.428658  4.270741e+06
# std      94.309923    95.694914    92.855227    94.313187  4.295971e+06
# min      16.139999    16.629999    14.980000    15.800000  1.185000e+05
# 25%      30.000000    30.650000    29.215000    29.884999  1.194350e+06
# 50%     156.334999   162.370002   153.150002   158.160004  3.180700e+06
# 75%     220.557495   224.099999   217.119999   220.022503  5.662100e+06
# max     287.670013   291.420013   280.399994   286.040009  3.716390e+07
#
#          Adj Close
# count  1692.000000
# mean    132.428658
# std      94.313187
# min      15.800000
# 25%      29.884999
# 50%     158.160004
# 75%     220.022503
# max     286.040009

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
tesla.nunique()
# Out:
# Date         1692
# Open         1464
# High         1470
# Low          1468
# Close        1528
# Volume       1676
# Adj Close    1528
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
tesla_data['Date'] = pd.to_datetime(tesla_data['Date'])
tesla['Date'] = pd.to_datetime(tesla['Date'])
tesla['Year']=tesla['Date'].dt.year
tesla['Month']=tesla['Date'].dt.month

# %%
averagevolumeyearly=tesla.groupby('Year')['Volume'].mean().sort_index()
averageclosedandvolumemonthly=tesla.groupby(['Year','Month']).agg({'Close': 'mean', 'Volume': 'mean'}).reset_index()
averagecloseyearly=tesla.groupby('Year')['Close'].mean().reset_index()
pol=tesla.groupby(['Year', 'Month']).apply(lambda x: x['Close'].iloc[-1]-x['Open'].iloc[0]).reset_index()

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# Pie chart

averagevolumeyearly=tesla.groupby('Year')['Volume'].mean().sort_index()
explode=[0,0,0,0,0,0,0,0.05]
plt.figure(figsize=(8, 8))
plt.pie(averagevolumeyearly, labels=averagevolumeyearly.index, autopct='%1.1f%%',explode=explode)
plt.title('Pie of Average Volume per Year')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ```
#
# # Pie chart
# ```
# ### I picked this pie chart as we had an univariate data made using groupby.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### We can see the average volume by each year and the increse and decrease by the yearly basis.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Yes the positive business aspect can be that we can see that the volume decreased overall by the years after increasing when tesla became popular creating low supply high demand incase increasing the price of it.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Scatter plot
averageclosedandvolumemonthly=tesla.groupby(['Year','Month']).agg({'Close': 'mean', 'Volume': 'mean'}).reset_index()

plt.figure(figsize=(10, 6))
plt.scatter(averageclosedandvolumemonthly['Close'], averageclosedandvolumemonthly['Volume'], c='blue', alpha=0.6)
plt.title('Scatter of Average Closed Price and Average Volume per Month')
plt.xlabel('Average Closed Price')
plt.ylabel('Average Volume')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ```
# # Scatter chart
#
# ```
# ### Because i wanted to find the corelation between the two above mentioned variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### We can see that mostly the closed price increase with respect to volume.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Yes the positive business aspect can be that we can see is that the volume decreases the closed price increases.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Scatter plot with best line according to me
averageclosedandvolumemonthly=tesla.groupby(['Year','Month']).agg({'Close': 'mean', 'Volume': 'mean'}).reset_index()
totalaveragevolume=averageclosedandvolumemonthly['Volume'].mean()
plt.figure(figsize=(10, 6))
plt.scatter(averageclosedandvolumemonthly['Close'], averageclosedandvolumemonthly['Volume'], c='blue', alpha=0.6)
plt.title('Scatter of Average Closed Price and Average Volume per Month')
plt.xlabel('Average Closed Price')
plt.ylabel('Average Volume')
plt.axhline(y=totalaveragevolume, color='red', linestyle='dashed', label=f'totalaveragevolume: {totalaveragevolume:.2f}')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ```
# # Scatter chart with line
#
# ```
# ### Because i wanted to find the corelation between the two above mentioned variables and the line of average volume.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### We can that mostly the closed price increase with respect to volume and also the average volume.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Yes the positive business aspect can be that we can see is that the volume decreases the closed price increases.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# Count chart
plt.figure(figsize=(10, 6))
sns.countplot(x='Year', data=tesla, hue='Month', palette='Set2', dodge=True)
plt.title('Count Plot of Frequencies by Year and Month')
plt.xlabel('Year')
plt.ylabel('Frequency')
plt.legend(title='Month', loc='upper right')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ```
# # Scatter chart
#
# ```
# ### Because i wanted to find the no of count by month and year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### The insights found are about the count of the values by monthly and yearly basis.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Yes the positive business aspect is having the count of each month for each year.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# Histogram


sns.set_style("darkgrid")
plt.figure(figsize=(10, 6))

n, bins, patches = plt.hist(tesla['Close'], bins=30, edgecolor='black')

cmap=plt.get_cmap('crest')
bin_centers = 0.5 * (bins[:-1] + bins[1:])
col_index = (bin_centers - min(bin_centers)) / (max(bin_centers) - min(bin_centers))

for idx, p in zip(col_index, patches):
    p.set_facecolor(cmap(idx))

plt.title('Distribution of Closing Price')
plt.xlabel('Closing Price')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ```
# # Histogram
#
# ```
# ### Because i wanted to find the count of all different closing prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### We can see that most of the closed price lies in the opening region of 0-40.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Yes the positive business aspect can be that we can see that the prices falcutuate.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# Box plot
plt.figure(figsize=(10, 6))
sns.boxplot(x=tesla['Close'], color='#B19CD9', linewidth=3, width=0.5)
plt.title('Box Plot of Closing Price')
plt.xlabel('Closing Price')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ```
# # Box plot
#
# ```
# ### Because i wanted to find the outliers in the closing prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### We can see that most of the closed price lies in the opening region of 0-40 and also the outliers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Yes the positive business aspect can be that we can remove the outliers and use the data for ml.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# Violin plot

columns = tesla.columns

fig, axes = plt.subplots(4, 2, figsize=(10, 12))

sns.violinplot(x=tesla[columns[0]], ax=axes[0, 0], color="#ffb3ba")
sns.violinplot(x=tesla[columns[1]], ax=axes[0, 1], color="#ffdfba")
sns.violinplot(x=tesla[columns[2]], ax=axes[1, 0], color="#ffffba")
sns.violinplot(x=tesla[columns[3]], ax=axes[1, 1], color="#baffc9")
sns.violinplot(x=tesla[columns[4]], ax=axes[2, 0], color="#bae1ff")
sns.violinplot(x=tesla[columns[5]], ax=axes[3, 0], color="#ffd8b1")
sns.violinplot(x=tesla[columns[6]], ax=axes[3, 1], color="#ffbcda")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ```
# # All Violin plot
#
# ```
# ### Because i wanted to find the outliers and the freuncy of all columns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### We can see all the outliers along with their frequencies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Yes the positive business aspect can be that we can see all the frequencies and outliers in a single plot.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# Kde
sns.kdeplot(data=tesla, x='Volume', hue='Year', fill=True, palette='husl', label='Volume')
plt.title('KDE for Volume all years')
plt.legend(title='Year',  labels=tesla['Year'].unique())
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ```
# # Kde
#
# ```
# ### Because i wanted to plot the volume by yearly with good readability.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### We can see that most of the high volume is of the two years.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Yes the positive business aspect can be about the finding of the probabilty density of volume.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Bar plot
averagecloseyearly=tesla.groupby('Year')['Close'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x='Year', y='Close', data=averagecloseyearly, palette='pastel')
plt.title('Average Closing Price of Tesla Stock by Year')
plt.xlabel('Year')
plt.ylabel('Average Closing Price')
plt.show()
# Out:
# <ipython-input-43-0b4ab8f1df6d>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Year', y='Close', data=averagecloseyearly, palette='pastel')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ```
# # Bar chart
#
# ```
# ### Because i wanted to plot between categorical and numerical data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### We can see that average closed price increasing year by year.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Yes the positive business aspect can be that we can see that if we purchase this stock the price will increase by the years.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# Categorical plot

sns.catplot(x='Year', data=tesla, kind='count', col='Year', col_wrap=2, height=3.5, palette='magma')
plt.title('Distribution of Tesla Closing Prices by Year')
plt.show()
# Out:
# <ipython-input-44-89cc3c2bd235>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='Year', data=tesla, kind='count', col='Year', col_wrap=2, height=3.5, palette='magma')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ```
# # Categorical chart
#
# ```
# ### Because i wanted to find more about the distribution of data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### We can see that we have incomplete data of starting and ending year.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Yes the positive business aspect can be that we found about the data counts that can help us in outlier removal.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
# Line plot

fig = px.line(tesla, x='Date', y=['Open', 'Close'], title='Daily Tesla Opening and Closing Prices',labels={'Date': 'Date', 'value': 'Price'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3a1d958f-69ea-4157-8a3c-f2e329a80c92" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a1d958f-69ea-4157-8a3c-f2e329a80c92")) {                    Plotly.newPlot(                        "3a1d958f-69ea-4157-8a3c-f2e329a80c92",                        [{"hovertemplate":"variable=Open\u003cbr\u003eDate=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Open","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Open","showlegend":true,"x":["2010-06-29T00:00:00","2010-06-30T00:00:00","2010-07-01T00:00:00","2010-07-02T00:00:00","2010-07-06T00:00:00","2010-07-07T00:00:00","2010-07-08T00:00:00","2010-07-09T00:00:00","2010-07-12T00:00:00","2010-07-13T00:00:00","2010-07-14T00:00:00","2010-07-15T00:00:00","2010-07-16T00:00:00","2010-07-19T00:00:00","2010-07-20T00:00:00","2010-07-21T00:00:00","2010-07-22T00:00:00","2010-07-23T00:00:00","2010-07-26T00:00:00","2010-07-27T00:00:00","2010-07-28T00:00:00","2010-07-29T00:00:00","2010-07-30T00:00:00","2010-08-02T00:00:00","2010-08-03T00:00:00","2010-08-04T00:00:00","2010-08-05T00:00:00","2010-08-06T00:00:00","2010-08-09T00:00:00","2010-08-10T00:00:00","2010-08-11T00:00:00","2010-08-12T00:00:00","2010-08-13T00:00:00","2010-08-16T00:00:00","2010-08-17T00:00:00","2010-08-18T00:00:00","2010-08-19T00:00:00","2010-08-20T00:00:00","2010-08-23T00:00:00","2010-08-24T00:00:00","2010-08-25T00:00:00","2010-08-26T00:00:00","2010-08-27T00:00:00","2010-08-30T00:00:00","2010-08-31T00:00:00","2010-09-01T00:00:00","2010-09-02T00:00:00","2010-09-03T00:00:00","2010-09-07T00:00:00","2010-09-08T00:00:00","2010-09-09T00:00:00","2010-09-10T00:00:00","2010-09-13T00:00:00","2010-09-14T00:00:00","2010-09-15T00:00:00","2010-09-16T00:00:00","2010-09-17T00:00:00","2010-09-20T00:00:00","2010-09-21T00:00:00","2010-09-22T00:00:00","2010-09-23T00:00:00","2010-09-24T00:00:00","2010-09-27T00:00:00","2010-09-28T00:00:00","2010-09-29T00:00:00","2010-09-30T00:00:00","2010-10-01T00:00:00","2010-10-04T00:00:00","2010-10-05T00:00:00","2010-10-06T00:00:00","2010-10-07T00:00:00","2010-10-08T00:00:00","2010-10-11T00:00:00","2010-10-12T00:00:00","2010-10-13T00:00:00","2010-10-14T00:00:00","2010-10-15T00:00:00","2010-10-18T00:00:00","2010-10-19T00:00:00","2010-10-20T00:00:00","2010-10-21T00:00:00","2010-10-22T00:00:00","2010-10-25T00:00:00","2010-10-26T00:00:00","2010-10-27T00:00:00","2010-10-28T00:00:00","2010-10-29T00:00:00","2010-11-01T00:00:00","2010-11-02T00:00:00","2010-11-03T00:00:00","2010-11-04T00:00:00","2010-11-05T00:00:00","2010-11-08T00:00:00","2010-11-09T00:00:00","2010-11-10T00:00:00","2010-11-11T00:00:00","2010-11-12T00:00:00","2010-11-15T00:00:00","2010-11-16T00:00:00","2010-11-17T00:00:00","2010-11-18T00:00:00","2010-11-19T00:00:00","2010-11-22T00:00:00","2010-11-23T00:00:00","2010-11-24T00:00:00","2010-11-26T00:00:00","2010-11-29T00:00:00","2010-11-30T00:00:00","2010-12-01T00:00:00","2010-12-02T00:00:00","2010-12-03T00:00:00","2010-12-06T00:00:00","2010-12-07T00:00:00","2010-12-08T00:00:00","2010-12-09T00:00:00","2010-12-10T00:00:00","2010-12-13T00:00:00","2010-12-14T00:00:00","2010-12-15T00:00:00","2010-12-16T00:00:00","2010-12-17T00:00:00","2010-12-20T00:00:00","2010-12-21T00:00:00","2010-12-22T00:00:00","2010-12-23T00:00:00","2010-12-27T00:00:00","2010-12-28T00:00:00","2010-12-29T00:00:00","2010-12-30T00:00:00","2010-12-31T00:00:00","2011-01-03T00:00:00","2011-01-04T00:00:00","2011-01-05T00:00:00","2011-01-06T00:00:00","2011-01-07T00:00:00","2011-01-10T00:00:00","2011-01-11T00:00:00","2011-01-12T00:00:00","2011-01-13T00:00:00","2011-01-14T00:00:00","2011-01-18T00:00:00","2011-01-19T00:00:00","2011-01-20T00:00:00","2011-01-21T00:00:00","201 ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ```
# # Line plot
#
# ```
# ### Because i wanted to find the daily open and closing prices and make it interactive.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### We can see that on a large level there is almost no difference in open and closing prices.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Yes the positive business aspect can be that we can find the daily data of the stock.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
# Line plot
pol=tesla.groupby(['Year', 'Month']).apply(lambda x: x['Close'].iloc[-1]-x['Open'].iloc[0]).reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(pol, x='Month', y=0, color='green')
plt.title('Monthly Profit/Loss of Tesla')
plt.xlabel('Month')
plt.ylabel('Profit/Loss')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ```
# # Line plot
#
# ```
# ### Because i wanted to find the monthly profit and loss and its a time series data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### We can see that there is no relation between month and p or l.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Yes the positive business aspect can be that we can see no relation between pol with month.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
# Line plot
volumemonthly=tesla.groupby(['Year', 'Month'])['Volume'].sum().reset_index()

plt.figure(figsize=(12, 6))
sns.lineplot(data=volumemonthly, x='Month', y='Volume', hue='Year', marker='o', palette='viridis', linewidth=2.5)
plt.title('Monthly Tesla Volume')
plt.xlabel('Month')
plt.ylabel('Volume')
plt.xticks(range(1,13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend(title='Year', title_fontsize='14', fontsize='12', loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ```
# # Line plot
#
# ```
# ### Because i wanted to find the average volume by month and year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### We can see that the average volume region.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### Yes the positive business aspect can be we see the volume being stabilised in a region.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
correlation=tesla.corr()

plt.figure(figsize=(16, 8))
sns.heatmap(correlation, annot=True, cmap='rocket')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-48-d003535ebb7c>:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ```
# # Correlation heatmap
#
# ```
# ### Because i wanted to find the correlation between each column.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### We can see that most of the columns depend on each other.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
columnsnames= ['Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close']

sns.pairplot(tesla_data[columnsnames],hue='Open')
plt.title('Pairplot',y=1.0)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ```
# # Pairplot
#
# ```
# ### Because i wanted to find charts between each column.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ### We can see the relationship between each column.

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %% [markdown]
# #### 1. Expand Contraction

# %%
# Expand Contraction

# %% [markdown]
# #### 2. Lower Casing

# %%
# Lower Casing

# %% [markdown]
# #### 3. Removing Punctuations

# %%
# Remove Punctuations

# %% [markdown]
# #### 4. Removing URLs & Removing words and digits contain digits.

# %%
# Remove URLs & Remove words and digits contain digits

# %% [markdown]
# #### 5. Removing Stopwords & Removing White spaces

# %%
# Remove Stopwords

# %%
# Remove White spaces

# %% [markdown]
# #### 6. Rephrase Text

# %%
# Rephrase Text

# %% [markdown]
# #### 7. Tokenization

# %%
# Tokenization

# %% [markdown]
# #### 8. Text Normalization

# %%
# Normalizing Text (i.e., Stemming, Lemmatization etc.)

# %% [markdown]
# ##### Which text normalization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 9. Part of speech tagging

# %%
# POS Taging

# %% [markdown]
# #### 10. Text Vectorization

# %%
# Vectorizing Text

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 5. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %%
# Transform Your data

# %% [markdown]
# ### 6. Data Scaling

# %%
# Scaling your data

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# Answer Here.

# %%
# DImensionality Reduction (If needed)

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 9. Handling Imbalanced Dataset

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# Answer Here.

# %%
# Handling Imbalanced Dataset (If needed)

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
# ML Model - 1 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 3

# %%
# ML Model - 3 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
